# %%
"""
🔬 EfficientNet-B7 GridSearch - Fair Comparison with Pretrained Weights

EXACT SAME PARAMETERS AS RESNET-101 & EEGNET:
1. ✅ Optimizer: Adam, AdamW, Adagrad
2. ✅ Activation: ReLU, LeakyReLU
3. ✅ L1: [0] (same as others)
4. ✅ L2: [0, 1e-4, 1e-3]
5. ✅ Early Stopping: patience=10
6. ✅ LR Scheduler: CosineAnnealingLR
7. ✅ Loss: SoftFocalLoss (gamma=3.0)
8. ✅ Data: Hybrid loading
9. ✅ CV: 3-fold
10. ✅ Pretrained: ImageNet weights

Total: 18 configs × 3 folds = 54 runs (~15 hours)
"""

import os
from pathlib import Path
import random
import time
import gc
import json
import warnings
from datetime import datetime
from itertools import product
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, WeightedRandomSampler

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score

# %%
# CELL 1: Setup & Imports

# %%
print("="*80)
print(" EfficientNet-B7 GridSearch - Pretrained ".center(80, "="))
print("="*80)
print(f"\nStarted: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# Reproducibility
def seed_everything(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

seed_everything(42)
print("✅ Seed: 42")

# Device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"✅ Device: {device}")
if torch.cuda.is_available():
    print(f"   GPU: {torch.cuda.get_device_name(0)}")
    torch.cuda.empty_cache()

# Paths
DATA_PKG = Path("data_package")
SPEC_DIR = Path("spec_hr_out")
RESULTS_DIR = Path("efficientnet_gridsearch_results")
RESULTS_DIR.mkdir(exist_ok=True)

print(f"\n✅ Results: {RESULTS_DIR}")
# Out:
# ================================================================================
# =================== EfficientNet-B7 GridSearch - Pretrained ====================
# ================================================================================
#
# Started: 2026-01-21 17:35:44
# ✅ Seed: 42
# ✅ Device: cuda:0
#    GPU: NVIDIA GeForce RTX 5060 Ti
#
# ✅ Results: efficientnet_gridsearch_results

# %%
# CELL 2: Load Data

# %%
meta_use = pd.read_csv(DATA_PKG / "meta_use.csv")
lbl = np.load(DATA_PKG / "labels.npz", allow_pickle=True)
y_soft = lbl["y_soft"]
w_conf = lbl["w_conf"]
classes = [str(c) for c in lbl["classes"]]
y_hard = y_soft.argmax(axis=1)

print("✅ Data loaded")
print(f"   Samples: {len(y_hard)}")
print(f"   Classes: {classes}")

# 3-fold CV (SAME AS RESNET & EEGNET & KAN)
N_FOLDS = 3
skf = StratifiedKFold(n_splits=N_FOLDS, shuffle=True, random_state=42)
folds = list(skf.split(meta_use, y_hard))
print(f"\n✅ Created {N_FOLDS}-fold CV")
# Out:
# ✅ Data loaded
#    Samples: 17089
#    Classes: ['seizure', 'lpd', 'gpd', 'lrda', 'grda', 'other']
#
# ✅ Created 3-fold CV

# %%
# CELL 3: Dataset Class

# %%
class SpecDataset(Dataset):
    def __init__(self, df, root_dir, y_soft, w_conf, F_target=81, T_target=600):
        self.df = df.reset_index(drop=True)
        self.root = Path(root_dir)
        self.y_soft = y_soft
        self.w_conf = w_conf
        self.F_target = F_target
        self.T_target = T_target

    def __len__(self):
        return len(self.df)

    def _center_crop_pad(self, x):
        C, F, T = x.shape
        if F >= self.F_target:
            f0 = (F - self.F_target) // 2
            x = x[:, f0:f0+self.F_target, :]
        else:
            pad = self.F_target - F
            x = np.pad(x, ((0,0),(pad//2, pad-pad//2),(0,0)), mode="constant")
        if T >= self.T_target:
            t0 = (T - self.T_target) // 2
            x = x[:, :, t0:t0+self.T_target]
        else:
            pad = self.T_target - T
            x = np.pad(x, ((0,0),(0,0),(pad//2, pad-pad//2)), mode="constant")
        return x.copy()

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        eid = int(row.eeg_id)
        
        npz = np.load(self.root / f"{eid}_hr.npz")
        x = npz["x"]
        x = self._center_crop_pad(x)
        x = torch.from_numpy(x).float()
        
        # Resize to 224x224 for EfficientNet
        x = F.interpolate(x.unsqueeze(0), size=(224, 224),
                          mode="bilinear", align_corners=False).squeeze(0)
        
        # Convert 4 channels to 3 channels (RGB) for pretrained model
        if x.size(0) == 4:
            # Average first 3 channels + repeat last channel
            x = torch.cat([x[:3].mean(0, keepdim=True).repeat(3, 1, 1)], dim=0)
        
        y = torch.from_numpy(self.y_soft[self.df.index[idx]]).float()
        w = torch.tensor(self.w_conf[self.df.index[idx]], dtype=torch.float32)
        
        return x, y, w

print("✅ Dataset ready")
# Out:
# ✅ Dataset ready

# %%
# CELL 4: EfficientNet-B7 Model (Pretrained)

# %%
from torchvision import models

class EfficientNetB7_Pretrained(nn.Module):
    """EfficientNet-B7 with pretrained ImageNet weights"""
    
    def __init__(self, n_classes=6, activation='relu', freeze_backbone=False):
        super().__init__()
        
        self.activation_name = activation
        
        # Load pretrained EfficientNet-B7
        self.backbone = models.efficientnet_b7(pretrained=True)
        
        # Optionally freeze backbone
        if freeze_backbone:
            for param in self.backbone.features.parameters():
                param.requires_grad = False
        
        # Replace classifier
        in_features = self.backbone.classifier[1].in_features
        self.backbone.classifier = nn.Identity()
        
        # Custom classifier head
        self.classifier = nn.Sequential(
            nn.Dropout(0.5),
            nn.Linear(in_features, 512),
            nn.BatchNorm1d(512),
            # Activation will be applied in forward()
            nn.Dropout(0.3),
            nn.Linear(512, n_classes)
        )
    
    def get_activation(self):
        """Return activation function based on config"""
        if self.activation_name == 'relu':
            return F.relu
        elif self.activation_name == 'leakyrelu':
            return lambda x: F.leaky_relu(x, negative_slope=0.01)
        else:
            return F.relu
    
    def forward(self, x):
        # Backbone features
        features = self.backbone(x)
        
        # Classifier with custom activation
        x = self.classifier[0](features)  # Dropout
        x = self.classifier[1](x)  # Linear
        x = self.classifier[2](x)  # BatchNorm
        x = self.get_activation()(x)  # Custom activation
        x = self.classifier[3](x)  # Dropout
        x = self.classifier[4](x)  # Linear
        
        return x

print("✅ EfficientNet-B7 model ready")
print("   Pretrained: ImageNet weights")
print("   Supports: ReLU, LeakyReLU")
# Out:
# ✅ EfficientNet-B7 model ready
#    Pretrained: ImageNet weights
#    Supports: ReLU, LeakyReLU

# %%
# CELL 5: SoftFocalLoss

# %%
class SoftFocalLoss(nn.Module):
    def __init__(self, alpha=None, gamma=3.0):
        super().__init__()
        self.alpha = alpha
        self.gamma = gamma
    
    def forward(self, logits, soft_targets, sample_weights=None):
        hard_targets = soft_targets.argmax(dim=1)
        probs = F.softmax(logits, dim=1)
        p_t = probs.gather(1, hard_targets.unsqueeze(1)).squeeze(1)
        ce_loss = -(soft_targets * F.log_softmax(logits, dim=1)).sum(dim=1)
        focal_weight = ((1 - p_t) ** self.gamma)
        loss = focal_weight * ce_loss
        
        if self.alpha is not None:
            alpha_t = self.alpha[hard_targets]
            loss = alpha_t * loss
        
        if sample_weights is not None:
            loss = loss * sample_weights
        
        return loss.mean()

print("✅ SoftFocalLoss ready")
# Out:
# ✅ SoftFocalLoss ready

# %%
# CELL 6: Hybrid Data Loader

# %%
def create_hybrid_loader(fold=0, target_ratio=0.4, weight_power=3.0, batch_size=8):
    tr_idx, va_idx = folds[fold]
    df_tr = meta_use.iloc[tr_idx]
    y_soft_tr, w_conf_tr = y_soft[tr_idx], w_conf[tr_idx]
    
    y_hard = y_soft_tr.argmax(axis=1)
    counts = np.bincount(y_hard, minlength=6)
    target = int(counts.max() * target_ratio)
    
    indices_add = []
    for i in range(6):
        mask = y_hard == i
        if mask.sum() < target:
            idx = np.where(mask)[0]
            n_add = target - mask.sum()
            indices_add.extend(np.random.choice(idx, n_add, replace=True))
    
    all_idx = np.concatenate([np.arange(len(y_hard)), indices_add])
    np.random.shuffle(all_idx)
    
    df_tr_over = df_tr.iloc[all_idx].reset_index(drop=True)
    y_soft_over, w_conf_over = y_soft_tr[all_idx], w_conf_tr[all_idx]
    
    y_hard_over = y_soft_over.argmax(axis=1)
    counts_over = np.bincount(y_hard_over, minlength=6)
    
    weights = (len(y_hard_over) / (counts_over + 1)) ** weight_power
    weights = torch.FloatTensor(weights / weights.sum() * 6)
    
    sample_weights = weights[y_hard_over].numpy()
    sampler = WeightedRandomSampler(
        weights=sample_weights,
        num_samples=len(sample_weights),
        replacement=True
    )
    
    ds_tr = SpecDataset(df_tr_over, SPEC_DIR, y_soft_over, w_conf_over)
    dl_tr = DataLoader(ds_tr, batch_size=batch_size, sampler=sampler, num_workers=0)
    
    ds_va = SpecDataset(meta_use.iloc[va_idx], SPEC_DIR, y_soft[va_idx], w_conf[va_idx])
    dl_va = DataLoader(ds_va, batch_size=batch_size, shuffle=False, num_workers=0)
    
    return dl_tr, dl_va, weights

print("✅ Hybrid loader ready (batch_size=8 for B7)")
# Out:
# ✅ Hybrid loader ready (batch_size=8 for B7)

# %%
# CELL 7: Evaluation

# %%
@torch.no_grad()
def evaluate_full(model, loader):
    model.eval()
    preds, targets = [], []
    
    for x, y, w in loader:
        x = x.to(device)
        logits = model(x)
        preds.append(logits.argmax(1).cpu().numpy())
        targets.append(y.argmax(1).cpu().numpy())
    
    y_pred = np.concatenate(preds)
    y_true = np.concatenate(targets)
    
    return {
        'accuracy': accuracy_score(y_true, y_pred),
        'precision': precision_score(y_true, y_pred, average='macro', zero_division=0),
        'recall': recall_score(y_true, y_pred, average='macro', zero_division=0),
        'f1': f1_score(y_true, y_pred, average='macro', zero_division=0),
    }

print("✅ Evaluation ready")
# Out:
# ✅ Evaluation ready

# %%
# CELL 8: Training Function

# %%
def train_one_config(fold, optimizer_name, activation, l1_lambda, l2_lambda,
                     lr=3e-4, batch_size=8, epochs=30, patience=10):
    
    # Data
    print(f"      [1/5] Data...", end=" ", flush=True)
    t0 = time.time()
    dl_tr, dl_va, class_weights = create_hybrid_loader(fold=fold, batch_size=batch_size)
    print(f"✓ ({time.time()-t0:.1f}s)", flush=True)
    
    # Model
    print(f"      [2/5] Model (EfficientNet-B7, {activation})...", end=" ", flush=True)
    t0 = time.time()
    model = EfficientNetB7_Pretrained(
        n_classes=6,
        activation=activation,
        freeze_backbone=False  # Fine-tune all layers
    ).to(device)
    print(f"✓ ({time.time()-t0:.1f}s)", flush=True)
    
    # Optimizer
    print(f"      [3/5] Optimizer ({optimizer_name}, L2={l2_lambda:.0e})...", end=" ", flush=True)
    if optimizer_name == 'adam':
        optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=l2_lambda)
    elif optimizer_name == 'adamw':
        optimizer = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=l2_lambda)
    elif optimizer_name == 'adagrad':
        optimizer = torch.optim.Adagrad(model.parameters(), lr=lr, weight_decay=l2_lambda)
    else:
        raise ValueError(f"Unknown optimizer: {optimizer_name}")
    print(f"✓", flush=True)
    
    # Loss & Scheduler
    print(f"      [4/5] Loss & Scheduler...", end=" ", flush=True)
    criterion = SoftFocalLoss(alpha=class_weights.to(device), gamma=3.0)
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=epochs)
    print(f"✓", flush=True)
    
    # Training
    print(f"      [5/5] Training (patience={patience}, L1={l1_lambda:.0e})...", flush=True)
    best_f1, best_state, no_improve = 0.0, None, 0
    
    for epoch in range(1, epochs + 1):
        model.train()
        train_loss, n = 0.0, 0
        
        for x, y, w in dl_tr:
            x, y, w = x.to(device), y.to(device), w.to(device)
            optimizer.zero_grad()
            logits = model(x)
            loss = criterion(logits, y, w)
            
            # L1 Regularization (SAME AS RESNET & EEGNET)
            if l1_lambda > 0:
                l1_norm = sum(p.abs().sum() for p in model.parameters())
                loss = loss + l1_lambda * l1_norm
            
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            optimizer.step()
            
            train_loss += loss.item() * x.size(0)
            n += x.size(0)
        
        train_loss /= n
        val_results = evaluate_full(model, dl_va)
        scheduler.step()
        
        # Early stopping
        if val_results['f1'] > best_f1:
            best_f1 = val_results['f1']
            best_state = {k: v.cpu().clone() for k, v in model.state_dict().items()}
            no_improve = 0
        else:
            no_improve += 1
            if no_improve >= patience:
                print(f"        Early stop at epoch {epoch}", flush=True)
                break
        
        if epoch % 5 == 0 or epoch == 1:
            print(f"        Epoch {epoch:2d}: F1={val_results['f1']:.4f}, Loss={train_loss:.4f}", flush=True)
        
        if epoch % 5 == 0:
            gc.collect()
            torch.cuda.empty_cache()
    
    if best_state:
        model.load_state_dict(best_state)
    
    final_results = evaluate_full(model, dl_va)
    
    del model, optimizer, scheduler, dl_tr, dl_va
    gc.collect()
    torch.cuda.empty_cache()
    
    return final_results

print("✅ Training function ready")
print("   Optimizers: Adam, AdamW, Adagrad")
print("   Activations: ReLU, LeakyReLU")
print("   L1/L2 regularization supported")
print("   Early stopping: patience=10")
# Out:
# ✅ Training function ready
#    Optimizers: Adam, AdamW, Adagrad
#    Activations: ReLU, LeakyReLU
#    L1/L2 regularization supported
#    Early stopping: patience=10

# %%
# CELL 9: Grid Configuration (SAME AS RESNET & EEGNET)

# %%
print("\n" + "="*80)
print(" EFFICIENTNET-B7 GRIDSEARCH - SAME AS RESNET-101 ".center(80, "="))
print("="*80)

# EXACT SAME PARAMS AS RESNET-101 & EEGNET
param_grid = {
    'optimizer': ['adam', 'adamw', 'adagrad'],  # 3 - SAME
    'activation': ['relu', 'leakyrelu'],        # 2 - SAME
    'l1_lambda': [0],                           # 1 - SAME (no L1)
    'l2_lambda': [0, 1e-4, 1e-3],              # 3 - SAME
}

fixed_params = {
    'lr': 3e-4,
    'batch_size': 8,  # Smaller batch for B7 memory
    'epochs': 30,
    'patience': 10,
}

keys = list(param_grid.keys())
values = list(param_grid.values())
combinations = list(product(*values))

print("\n📋 HYPERPARAMETER GRID:")
print("-"*80)
print(f"  Optimizer:   {param_grid['optimizer']}")
print(f"  Activation:  {param_grid['activation']}")
print(f"  L1 lambda:   {param_grid['l1_lambda']}")
print(f"  L2 lambda:   {param_grid['l2_lambda']}")

print("\n📊 GRIDSEARCH STATISTICS:")
print("-"*80)
print(f"  Total combinations: {len(combinations)}")
print(f"  Folds per config:   {N_FOLDS}")
print(f"  Total trainings:    {len(combinations) * N_FOLDS}")
print(f"  Est. time per run:  ~15-20 min (B7 is larger)")
print(f"  Est. total time:    ~{len(combinations) * N_FOLDS * 17.5 / 60:.1f} hours")

print("\n📝 ALL COMBINATIONS:")
print("-"*80)
for i, combo in enumerate(combinations, 1):
    params = dict(zip(keys, combo))
    print(f"  {i:2d}. {params['optimizer']:7s} + {params['activation']:10s} + "
          f"L1={params['l1_lambda']:.0e} + L2={params['l2_lambda']:.0e}")

print("\n🎯 TARGETS TO BEAT:")
print("-"*80)
print("  EEGNet (baseline):     F1 = 0.3281")
print("  EEGNet (tuned):        F1 = 0.3892")
print("  ResNet-101 (tuned):    F1 = 0.5585")
print("  EfficientNet-B7:       F1 = ??? (GOAL: > 0.5585)")

print("\n⏱️  TIMELINE:")
print("-"*80)
current_time = datetime.now()
finish_time = current_time + pd.Timedelta(hours=len(combinations) * N_FOLDS * 17.5 / 60)
print(f"  Start:  {current_time.strftime('%Y-%m-%d %H:%M')}")
print(f"  Finish: {finish_time.strftime('%Y-%m-%d %H:%M')} (approx)")

print("\n💾 AUTO-SAVE:")
print("-"*80)
print(f"  {RESULTS_DIR}/efficientnet_gridsearch_progress.json")
print(f"  {RESULTS_DIR}/efficientnet_gridsearch_final.json")
# Out:
# ================================================================================
# =============== EFFICIENTNET-B7 GRIDSEARCH - SAME AS RESNET-101 ================
# ================================================================================
#
# 📋 HYPERPARAMETER GRID:
# --------------------------------------------------------------------------------
#   Optimizer:   ['adam', 'adamw', 'adagrad']
#   Activation:  ['relu', 'leakyrelu']
#   L1 lambda:   [0]
#   L2 lambda:   [0, 0.0001, 0.001]
#
# 📊 GRIDSEARCH STATISTICS:
# --------------------------------------------------------------------------------
#   Total combinations: 18
#   Folds per config:   3
#   Total trainings:    54
#   Est. time per run:  ~15-20 min (B7 is larger)
#   Est. total time:    ~15.8 hours
#
# 📝 ALL COMBINATIONS:
# --------------------------------------------------------------------------------
#    1. adam    + relu       + L1=0e+00 + L2=0e+00
#    2. adam    + relu       + L1=0e+00 + L2=1e-04
#    3. adam    + relu       + L1=0e+00 + L2=1e-03
#    4. adam    + leakyrelu  + L1=0e+00 + L2=0e+00
#    5. adam    + leakyrelu  + L1=0e+00 + L2=1e-04
#    6. adam    + leakyrelu  + L1=0e+00 + L2=1e-03
#    7. adamw   + relu       + L1=0e+00 + L2=0e+00
#    8. adamw   + relu       + L1=0e+00 + L2=1e-04
#    9. adamw   + relu       + L1=0e+00 + L2=1e-03
#   10. adamw   + leakyrelu  + L1=0e+00 + L2=0e+00
#   11. adamw   + leakyrelu  + L1=0e+00 + L2=1e-04
#   12. adamw   + leakyrelu  + L1=0e+00 + L2=1e-03
#   13. adagrad + relu       + L1=0e+00 + L2=0e+00
#   14. adagrad + relu       + L1=0e+00 + L2=1e-04
#   15. adagrad + relu       + L1=0e+00 + L2=1e-03
#   16. adagrad + leakyrelu  + L1=0e+00 + L2=0e+00
#   17. adagrad + leakyrelu  + L1=0e+00 + L2=1e-04
#   18. adagrad + leakyrelu  + L1=0e+00 + L2=1e-03
#
# 🎯 TARGETS TO BEAT:
# --------------------------------------------------------------------------------
#   EEGNet (baseline):     F1 = 0.3281
#   EEGNet (tuned):        F1 = 0.3892
#   ResNet-101 (tuned):    F1 = 0.5585
#   EfficientNet-B7:       F1 = ??? (GOAL: > 0.5585)
#
# ⏱️  TIMELINE:
# --------------------------------------------------------------------------------
#   Start:  2026-01-21 17:43
#   Finish: 2026-01-22 09:28 (approx)
#
# 💾 AUTO-SAVE:
# --------------------------------------------------------------------------------
#   efficientnet_gridsearch_results/efficientnet_gridsearch_progress.json
#   efficientnet_gridsearch_results/efficientnet_gridsearch_final.json

# %%
# CELL 10: Run GridSearch

# %%
print("\n" + "="*80)
print(" STARTING GRIDSEARCH ".center(80, "="))
print("="*80)
print(f"Started: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n")

all_results = []
start_time = time.time()

for combo_idx, combo in enumerate(combinations, 1):
    params = dict(zip(keys, combo))
    
    print("\n" + "="*80)
    print(f" CONFIG {combo_idx}/{len(combinations)} ".center(80, "="))
    print("="*80)
    print(f"  Optimizer: {params['optimizer']}")
    print(f"  Activation: {params['activation']}")
    print(f"  L1: {params['l1_lambda']:.0e}")
    print(f"  L2: {params['l2_lambda']:.0e}")
    print("-"*80)
    
    fold_results = []
    
    for fold in range(N_FOLDS):
        print(f"\n    Fold {fold+1}/{N_FOLDS}...", flush=True)
        fold_start = time.time()
        
        try:
            result = train_one_config(
                fold=fold,
                optimizer_name=params['optimizer'],
                activation=params['activation'],
                l1_lambda=params['l1_lambda'],
                l2_lambda=params['l2_lambda'],
                **fixed_params
            )
            fold_results.append(result)
            print(f"\n    ✓ Fold {fold+1}: F1={result['f1']:.4f} ({(time.time()-fold_start)/60:.1f} min)", flush=True)
        except Exception as e:
            print(f"\n    ✗ Error: {e}", flush=True)
            fold_results.append({'f1': 0.0, 'accuracy': 0.0, 'precision': 0.0, 'recall': 0.0})
    
    mean_metrics = {
        'f1': np.mean([r['f1'] for r in fold_results]),
        'accuracy': np.mean([r['accuracy'] for r in fold_results]),
        'precision': np.mean([r['precision'] for r in fold_results]),
        'recall': np.mean([r['recall'] for r in fold_results]),
        'f1_std': np.std([r['f1'] for r in fold_results]),
    }
    
    result_entry = {
        'config_id': combo_idx,
        'params': params,
        'mean_metrics': mean_metrics,
        'fold_results': fold_results,
        'timestamp': datetime.now().strftime('%Y-%m-%d %H:%M:%S'),
    }
    all_results.append(result_entry)
    
    print(f"\n  Mean F1: {mean_metrics['f1']:.4f} ± {mean_metrics['f1_std']:.4f}")
    print(f"  Mean Acc: {mean_metrics['accuracy']:.4f}")
    
    # Auto-save
    with open(RESULTS_DIR / 'efficientnet_gridsearch_progress.json', 'w') as f:
        json.dump(all_results, f, indent=2, default=str)
    print(f"  💾 Saved", flush=True)

# Final save
with open(RESULTS_DIR / 'efficientnet_gridsearch_final.json', 'w') as f:
    json.dump({
        'all_results': all_results,
        'param_grid': param_grid,
        'fixed_params': fixed_params,
        'total_time_hours': (time.time() - start_time) / 3600,
    }, f, indent=2, default=str)

print("\n" + "="*80)
print(" GRIDSEARCH COMPLETE ".center(80, "="))
print("="*80)
print(f"Total time: {(time.time()-start_time)/3600:.2f} hours")
# Out:
# ================================================================================
# ============================= STARTING GRIDSEARCH ==============================
# ================================================================================
# Started: 2026-01-21 17:45:06
#
#
# ================================================================================
# ================================= CONFIG 1/18 ==================================
# ================================================================================
#   Optimizer: adam
#   Activation: relu
#   L1: 0e+00
#   L2: 0e+00
# --------------------------------------------------------------------------------
#
#     Fold 1/3...
#       [1/5] Data... ✓ (0.0s)
#       [2/5] Model (EfficientNet-B7, relu)... Downloading: "https://download.pytorch.org/models/efficientnet_b7_lukemelas-c5b4e57e.pth" to C:\Users\numpppy/.cache\torch\hub\checkpoints\efficientnet_b7_lukemelas-c5b4e57e.pth
# 100%|██████████| 255M/255M [00:22<00:00, 11.7MB/s]
# ✓ (24.1s)
#       [3/5] Optimizer (adam, L2=0e+00)... ✓
#       [4/5] Loss & Scheduler... ✓
#       [5/5] Training (patience=10, L1=0e+00)...
#         Epoch  1: F1=0.2963, Loss=0.8956
#         Epoch  5: F1=0.3420, Loss=0.2265
#         Epoch 10: F1=0.3540, Loss=0.1220
#         Epoch 15: F1=0.4210, Loss=0.0980
#         Epoch 20: F1=0.4847, Loss=0.0815
#         Epoch 25: F1=0.5171, Loss=0.0809
#         Epoch 30: F1=0.5180, Loss=0.0714
#
#     ✓ Fold 1: F1=0.5181 (174.8 min)
#
#     Fold 2/3...
#       [1/5] Data... ✓ (0.0s)
#       [2/5] Model (EfficientNet-B7, relu)... ✓ (0.7s)
#       [3/5] Optimizer (adam, L2=0e+00)... ✓
#       [4/5] Loss & Scheduler... ✓
#       [5/5] Training (patience=10, L1=0e+00)...
#         Epoch  1: F1=0.3086, Loss=0.8989
#         Epoch  5: F1=0.3585, Loss=0.2052
#         Epoch 10: F1=0.3621, Loss=0.1054
#         Epoch 15: F1=0.4007, Loss=0.0988
#         Epoch 20: F1=0.4930, Loss=0.0800
#         Epoch 25: F1=0.5147, Loss=0.0696
#         Epoch 30: F1=0.5199, Loss=0.0757
#
#     ✓ Fold 2: F1=0.5213 (158.2 min)
#
#     Fold 3/3...
#       [1/5] Data... ✓ (0.0s)
#       [2/5] Model (EfficientNet-B7, relu)... ✓ (0.7s)
#       [3/5] Optimizer (adam, L2=0e+00)... ✓
#       [4/5] Loss & Scheduler... ✓
#       [5/5] Training (patience=10, L1=0e+00)...
#
#     ✗ Error: Expected more than 1 value per channel when training, got input size torch.Size([1, 512])
#
#   Mean F1: 0.3465 ± 0.2450
#   Mean Acc: 0.3923
#   💾 Saved
#
# ================================================================================
# ================================= CONFIG 2/18 ==================================
# ================================================================================
#   Optimizer: adam
#   Activation: relu
#   L1: 0e+00
#   L2: 1e-04
# --------------------------------------------------------------------------------
#
#     Fold 1/3...
#       [1/5] Data... ✓ (0.0s)
#       [2/5] Model (EfficientNet-B7, relu)... ✓ (0.7s)
#       [3/5] Optimizer (adam, L2=1e-04)... ✓
#       [4/5] Loss & Scheduler... ✓
#       [5/5] Training (patience=10, L1=0e+00)...
#         Epoch  1: F1=0.2989, Loss=0.9399
#         Epoch  5: F1=0.3283, Loss=0.3585
#         Epoch 10: F1=0.3393, Loss=0.2069
#         Early stop at epoch 12
#
#     ✓ Fold 1: F1=0.3591 (64.3 min)
#
#     Fold 2/3...
#       [1/5] Data... ✓ (0.0s)
#       [2/5] Model (EfficientNet-B7, relu)... ✓ (0.7s)
#       [3/5] Optimizer (adam, L2=1e-04)... ✓
#       [4/5] Loss & Scheduler... ✓
#       [5/5] Training (patience=10, L1=0e+00)...
#         Epoch  1: F1=0.2839, Loss=0.8824
#         Epoch  5: F1=0.2461, Loss=0.3660
#         Epoch 10: F1=0.3151, Loss=0.2126
#         Early stop at epoch 14
#
#     ✓ Fold 2: F1=0.3652 (74.9 min)
#
#     Fold 3/3...
#       [1/5] Data... ✓ (0.0s)
#       [2/5] Model (EfficientNet-B7, relu)... ✓ (0.7s)
#       [3/5] Optimizer (adam, L2=1e-04)... ✓
#       [4/5] Loss & Scheduler... ✓
#       [5/5] Training (patience=10, L1=0e+00)...
#
#     ✗ Error: Expected more than 1 value per channel when training, got input size torch.Size([1, 512])
#
#   Mean F1: 0.2414 ± 0.1707
#   Mean Acc: 0.2180
#   💾 Saved
#
# ================================================================================
# ================================= CONFIG 3/18 ==================================
# ================================================================================
#   Optimizer: adam
#   Activation: relu
#   L1: 0e+00
#   L2: 1e-03
# --------------------------------------------------------------------------------
#
#     Fold 1/3...
#       [1/5] Data... ✓ (0.0s)
#       [2/5] Model (EfficientNet-B7, relu)... ✓ (0.8s)
#       [3/5] Optimizer (adam, L2=1e-03)... ✓
#       [4/5] Loss & Scheduler... ✓
#       [5/5] Training (patience=10, L1=0e+00)...
#         Epoch  1: F1=0.1517, Loss=1.0274
#         Epoch  5: F1=0.3226, Loss=0.6367
#         Epoch 10: F1=0.2766, Loss=0.5666
#         Epoch 15: F1=0.2384, Loss=0.5163
#         Early stop at epoch 19
#
#     ✓ Fold 1: F1=0.3278 (101.3 min)
#
#     Fold 2/3...
#       [1/5] Data... ✓ (0.0s)
#       [2/5] Model (EfficientNet-B7, relu)... ✓ (0.7s)
#       [3/5] Optimizer (adam, L2=1e-03)... ✓
#       [4/5] Loss & Scheduler... ✓
#       [5/5] Training (patience=10, L1=0e+00)...
#         Epoch  1: F1=0.1073, Loss=1.0445
#         Epoch  5: F1=0.3214, Loss=0.6352
#         Epoch 10: F1=0.3142, Loss=0.5724
#         Early stop at epoch 13
#
#     ✓ Fold 2: F1=0.3286 (69.6 min)
#
#     Fold 3/3...
#       [1/5] Data... ✓ (0.0s)
#       [2/5] Model (EfficientNet-B7, relu)... ✓ (0.7s)
#       [3/5] Optimizer (adam, L2=1e-03)... ✓
#       [4/5] Loss & Scheduler... ✓
#       [5/5] Training (patience=10, L1=0e+00)...
#
#     ✗ Error: Expected more than 1 value per channel when training, got input size torch.Size([1, 512])
#
#   Mean F1: 0.2188 ± 0.1547
#   Mean Acc: 0.1933
#   💾 Saved
#
# ================================================================================
# ================================= CONFIG 4/18 ==================================
# ================================================================================
#   Optimizer: adam
#   Activation: leakyrelu
#   L1: 0e+00
#   L2: 0e+00
# --------------------------------------------------------------------------------
#
#     Fold 1/3...
#       [1/5] Data... ✓ (0.0s)
#       [2/5] Model (EfficientNet-B7, leakyrelu)... ✓ (0.7s)
#       [3/5] Optimizer (adam, L2=0e+00)... ✓
#       [4/5] Loss & Scheduler... ✓
#       [5/5] Training (patience=10, L1=0e+00)...
#         Epoch  1: F1=0.2936, Loss=0.8830
#         Epoch  5: F1=0.3525, Loss=0.2357
#         Epoch 10: F1=0.3610, Loss=0.1239
#         Epoch 15: F1=0.4602, Loss=0.1048
#         Epoch 20: F1=0.4876, Loss=0.0869
#         Epoch 25: F1=0.5184, Loss=0.0784
#         Epoch 30: F1=0.5269, Loss=0.0730
#
#     ✓ Fold 1: F1=0.5278 (158.1 min)
#
#     Fold 2/3...
#       [1/5] Data... ✓ (0.0s)
#       [2/5] Model (EfficientNet-B7, leakyrelu)... ✓ (0.7s)
#       [3/5] Optimizer (adam, L2=0e+00)... ✓
#       [4/5] Loss & Scheduler... ✓
#       [5/5] Training (patience=10, L1=0e+00)...
#         Epoch  1: F1=0.3218, Loss=0.9252
#         Epoch  5: F1=0.3534, Loss=0.2432
#         Epoch 10: F1=0.3600, Loss=0.1273
#         Epoch 15: F1=0.4098, Loss=0.0887
#         Epoch 20: F1=0.4674, Loss=0.0807
#         Epoch 25: F1=0.5070, Loss=0.0742
#         Epoch 30: F1=0.5119, Loss=0.0752
#
#     ✓ Fold 2: F1=0.5138 (157.3 min)
#
#     Fold 3/3...
#       [1/5] Data... ✓ (0.0s)
#       [2/5] Model (EfficientNet-B7, leakyrelu)... ✓ (0.8s)
#       [3/5] Optimizer (adam, L2=0e+00)... ✓
#       [4/5] Loss & Scheduler... ✓
#       [5/5] Training (patience=10, L1=0e+00)...
#
#     ✗ Error: Expected more than 1 value per channel when training, got input size torch.Size([1, 512])
#
#   Mean F1: 0.3472 ± 0.2456
#   Mean Acc: 0.3890
#   💾 Saved
#
# ================================================================================
# ================================= CONFIG 5/18 ==================================
# ================================================================================
#   Optimizer: adam
#   Activation: leakyrelu
#   L1: 0e+00
#   L2: 1e-04
# --------------------------------------------------------------------------------
#
#     Fold 1/3...
#       [1/5] Data... ✓ (0.0s)
#       [2/5] Model (EfficientNet-B7, leakyrelu)... ✓ (0.7s)
#       [3/5] Optimizer (adam, L2=1e-04)... ✓
#       [4/5] Loss & Scheduler... ✓
#       [5/5] Training (patience=10, L1=0e+00)...
#         Epoch  1: F1=0.2638, Loss=0.8949
#         Epoch  5: F1=0.3329, Loss=0.3543
#         Epoch 10: F1=0.3259, Loss=0.2114
#         Epoch 15: F1=0.3490, Loss=0.1533
#         Epoch 20: F1=0.3557, Loss=0.1039
#         Epoch 25: F1=0.3821, Loss=0.0874
#         Epoch 30: F1=0.3911, Loss=0.0877
#
#     ✓ Fold 1: F1=0.3976 (159.8 min)
#
#     Fold 2/3...
#       [1/5] Data... ✓ (0.0s)
#       [2/5] Model (EfficientNet-B7, leakyrelu)... ✓ (0.7s)
#       [3/5] Optimizer (adam, L2=1e-04)... ✓
#       [4/5] Loss & Scheduler... ✓
#       [5/5] Training (patience=10, L1=0e+00)...
#         Epoch  1: F1=0.2569, Loss=0.9026
#         Epoch  5: F1=0.3454, Loss=0.3493
#         Epoch 10: F1=0.3450, Loss=0.2054
#         Epoch 15: F1=0.3473, Loss=0.1499
#         Epoch 20: F1=0.3436, Loss=0.1055
#         Epoch 25: F1=0.3756, Loss=0.0964
#         Epoch 30: F1=0.3816, Loss=0.0827
#
#     ✓ Fold 2: F1=0.3829 (160.2 min)
#
#     Fold 3/3...
#       [1/5] Data... ✓ (0.0s)
#       [2/5] Model (EfficientNet-B7, leakyrelu)... ✓ (0.7s)
#       [3/5] Optimizer (adam, L2=1e-04)... ✓
#       [4/5] Loss & Scheduler... ✓
#       [5/5] Training (patience=10, L1=0e+00)...
#
#     ✗ Error: Expected more than 1 value per channel when training, got input size torch.Size([1, 512])
#
#   Mean F1: 0.2602 ± 0.1841
#   Mean Acc: 0.2592
#   💾 Saved
#
# ================================================================================
# ================================= CONFIG 6/18 ==================================
# ================================================================================
#   Optimizer: adam
#   Activation: leakyrelu
#   L1: 0e+00
#   L2: 1e-03
# --------------------------------------------------------------------------------
#
#     Fold 1/3...
#       [1/5] Data... ✓ (0.0s)
#       [2/5] Model (EfficientNet-B7, leakyrelu)... ✓ (0.7s)
#       [3/5] Optimizer (adam, L2=1e-03)... ✓
#       [4/5] Loss & Scheduler... ✓
#       [5/5] Training (patience=10, L1=0e+00)...
#         Epoch  1: F1=0.1273, Loss=1.0795
#         Epoch  5: F1=0.3086, Loss=0.6176
#         Epoch 10: F1=0.3110, Loss=0.5712
#         Early stop at epoch 14
#
#     ✓ Fold 1: F1=0.3476 (78.1 min)
#
#     Fold 2/3...
#       [1/5] Data... ✓ (0.0s)
#       [2/5] Model (EfficientNet-B7, leakyrelu)... ✓ (0.7s)
#       [3/5] Optimizer (adam, L2=1e-03)... ✓
#       [4/5] Loss & Scheduler... ✓
#       [5/5] Training (patience=10, L1=0e+00)...
#         Epoch  1: F1=0.2075, Loss=1.0164
#         Epoch  5: F1=0.3079, Loss=0.6235
#         Epoch 10: F1=0.3315, Loss=0.5744
#         Epoch 15: F1=0.3211, Loss=0.5128
#         Epoch 20: F1=0.3497, Loss=0.4598
#         Epoch 25: F1=0.3351, Loss=0.4026
#         Early stop at epoch 30
#
#     ✓ Fold 2: F1=0.3497 (160.5 min)
#
#     Fold 3/3...
#       [1/5] Data... ✓ (0.0s)
#       [2/5] Model (EfficientNet-B7, leakyrelu)... ✓ (0.7s)
#       [3/5] Optimizer (adam, L2=1e-03)... ✓
#       [4/5] Loss & Scheduler... ✓
#       [5/5] Training (patience=10, L1=0e+00)...
#
#     ✗ Error: Expected more than 1 value per channel when training, got input size torch.Size([1, 512])
#
#   Mean F1: 0.2324 ± 0.1644
#   Mean Acc: 0.2263
#   💾 Saved
#
# ================================================================================
# ================================= CONFIG 7/18 ==================================
# ================================================================================
#   Optimizer: adamw
#   Activation: relu
#   L1: 0e+00
#   L2: 0e+00
# --------------------------------------------------------------------------------
#
#     Fold 1/3...
#       [1/5] Data... ✓ (0.0s)
#       [2/5] Model (EfficientNet-B7, relu)... ✓ (0.8s)
#       [3/5] Optimizer (adamw, L2=0e+00)... ✓
#       [4/5] Loss & Scheduler... ✓
#       [5/5] Training (patience=10, L1=0e+00)...
#         Epoch  1: F1=0.2996, Loss=0.8903
#         Epoch  5: F1=0.3556, Loss=0.2273
#         Epoch 10: F1=0.3570, Loss=0.1180
#         Epoch 15: F1=0.4291, Loss=0.0907
#         Epoch 20: F1=0.4814, Loss=0.0777
#         Epoch 25: F1=0.5026, Loss=0.0677
#         Epoch 30: F1=0.5020, Loss=0.0705
#
#     ✓ Fold 1: F1=0.5041 (158.5 min)
#
#     Fold 2/3...
#       [1/5] Data... ✓ (0.0s)
#       [2/5] Model (EfficientNet-B7, relu)... ✓ (0.8s)
#       [3/5] Optimizer (adamw, L2=0e+00)... ✓
#       [4/5] Loss & Scheduler... ✓
#       [5/5] Training (patience=10, L1=0e+00)...
#         Epoch  1: F1=0.2359, Loss=0.9190
#         Epoch  5: F1=0.3495, Loss=0.2518
#         Epoch 10: F1=0.3804, Loss=0.1280
#         Epoch 15: F1=0.4113, Loss=0.0938
#         Epoch 20: F1=0.4674, Loss=0.0816
#         Epoch 25: F1=0.5058, Loss=0.0735
#         Epoch 30: F1=0.5126, Loss=0.0739
#
#     ✓ Fold 2: F1=0.5159 (158.5 min)
#
#     Fold 3/3...
#       [1/5] Data... ✓ (0.0s)
#       [2/5] Model (EfficientNet-B7, relu)... ✓ (0.7s)
#       [3/5] Optimizer (adamw, L2=0e+00)... ✓
#       [4/5] Loss & Scheduler... ✓
#       [5/5] Training (patience=10, L1=0e+00)...
#
#     ✗ Error: Expected more than 1 value per channel when training, got input size torch.Size([1, 512])
#
#   Mean F1: 0.3400 ± 0.2405
#   Mean Acc: 0.3871
#   💾 Saved
#
# ================================================================================
# ================================= CONFIG 8/18 ==================================
# ================================================================================
#   Optimizer: adamw
#   Activation: relu
#   L1: 0e+00
#   L2: 1e-04
# --------------------------------------------------------------------------------
#
#     Fold 1/3...
#       [1/5] Data... ✓ (0.0s)
#       [2/5] Model (EfficientNet-B7, relu)... ✓ (0.7s)
#       [3/5] Optimizer (adamw, L2=1e-04)... ✓
#       [4/5] Loss & Scheduler... ✓
#       [5/5] Training (patience=10, L1=0e+00)...
#         Epoch  1: F1=0.2452, Loss=0.8829
#         Epoch  5: F1=0.3599, Loss=0.2188
#         Epoch 10: F1=0.3526, Loss=0.1214
#         Epoch 15: F1=0.4080, Loss=0.0938
#         Epoch 20: F1=0.4645, Loss=0.0735
#         Epoch 25: F1=0.5107, Loss=0.0712
#         Epoch 30: F1=0.5085, Loss=0.0735
#
#     ✓ Fold 1: F1=0.5168 (160.4 min)
#
#     Fold 2/3...
#       [1/5] Data... ✓ (0.0s)
#       [2/5] Model (EfficientNet-B7, relu)... ✓ (0.7s)
#       [3/5] Optimizer (adamw, L2=1e-04)... ✓
#       [4/5] Loss & Scheduler... ✓
#       [5/5] Training (patience=10, L1=0e+00)...
#         Epoch  1: F1=0.2975, Loss=0.8565
#         Epoch  5: F1=0.3503, Loss=0.2124
#         Epoch 10: F1=0.3695, Loss=0.1196
#         Epoch 15: F1=0.4388, Loss=0.0831
#         Epoch 20: F1=0.4996, Loss=0.0798
#         Epoch 25: F1=0.5076, Loss=0.0701
#         Epoch 30: F1=0.5201, Loss=0.0749
#
#     ✓ Fold 2: F1=0.5250 (159.6 min)
#
#     Fold 3/3...
#       [1/5] Data... ✓ (0.0s)
#       [2/5] Model (EfficientNet-B7, relu)... ✓ (0.7s)
#       [3/5] Optimizer (adamw, L2=1e-04)... ✓
#       [4/5] Loss & Scheduler... ✓
#       [5/5] Training (patience=10, L1=0e+00)...
#
#     ✗ Error: Expected more than 1 value per channel when training, got input size torch.Size([1, 512])
#
#   Mean F1: 0.3472 ± 0.2456
#   Mean Acc: 0.3847
#   💾 Saved
#
# ================================================================================
# ================================= CONFIG 9/18 ==================================
# ================================================================================
#   Optimizer: adamw
#   Activation: relu
#   L1: 0e+00
#   L2: 1e-03
# --------------------------------------------------------------------------------
#
#     Fold 1/3...
#       [1/5] Data... ✓ (0.0s)
#       [2/5] Model (EfficientNet-B7, relu)... ✓ (0.7s)
#       [3/5] Optimizer (adamw, L2=1e-03)... ✓
#       [4/5] Loss & Scheduler... ✓
#       [5/5] Training (patience=10, L1=0e+00)...
#         Epoch  1: F1=0.3120, Loss=0.9247
#         Epoch  5: F1=0.3661, Loss=0.2507
#         Epoch 10: F1=0.3788, Loss=0.1189
#         Epoch 15: F1=0.4360, Loss=0.0942
#         Epoch 20: F1=0.5041, Loss=0.0801
#         Epoch 25: F1=0.5132, Loss=0.0730
#         Epoch 30: F1=0.5178, Loss=0.0749
#
#     ✓ Fold 1: F1=0.5178 (158.8 min)
#
#     Fold 2/3...
#       [1/5] Data... ✓ (0.0s)
#       [2/5] Model (EfficientNet-B7, relu)... ✓ (0.7s)
#       [3/5] Optimizer (adamw, L2=1e-03)... ✓
#       [4/5] Loss & Scheduler... ✓
#       [5/5] Training (patience=10, L1=0e+00)...
#         Epoch  1: F1=0.2724, Loss=0.8617
#         Epoch  5: F1=0.3333, Loss=0.2228
#         Epoch 10: F1=0.3662, Loss=0.1316
#         Epoch 15: F1=0.4487, Loss=0.0910
#         Epoch 20: F1=0.5052, Loss=0.0844
#         Epoch 25: F1=0.5246, Loss=0.0770
#         Epoch 30: F1=0.5182, Loss=0.0827
#
#     ✓ Fold 2: F1=0.5246 (158.7 min)
#
#     Fold 3/3...
#       [1/5] Data... ✓ (0.0s)
#       [2/5] Model (EfficientNet-B7, relu)... ✓ (0.7s)
#       [3/5] Optimizer (adamw, L2=1e-03)... ✓
#       [4/5] Loss & Scheduler... ✓
#       [5/5] Training (patience=10, L1=0e+00)...
#
#     ✗ Error: Expected more than 1 value per channel when training, got input size torch.Size([1, 512])
#
#   Mean F1: 0.3475 ± 0.2457
#   Mean Acc: 0.3922
#   💾 Saved
#
# ================================================================================
# ================================= CONFIG 10/18 =================================
# ================================================================================
#   Optimizer: adamw
#   Activation: leakyrelu
#   L1: 0e+00
#   L2: 0e+00
# --------------------------------------------------------------------------------
#
#     Fold 1/3...
#       [1/5] Data... ✓ (0.0s)
#       [2/5] Model (EfficientNet-B7, leakyrelu)... ✓ (0.7s)
#       [3/5] Optimizer (adamw, L2=0e+00)... ✓
#       [4/5] Loss & Scheduler... ✓
#       [5/5] Training (patience=10, L1=0e+00)...
#         Epoch  1: F1=0.2527, Loss=0.8730
#         Epoch  5: F1=0.3420, Loss=0.2382
#         Epoch 10: F1=0.3604, Loss=0.1275
#         Epoch 15: F1=0.4401, Loss=0.1020
#         Epoch 20: F1=0.4645, Loss=0.0864
#         Epoch 25: F1=0.5145, Loss=0.0787
#         Epoch 30: F1=0.5228, Loss=0.0793
#
#     ✓ Fold 1: F1=0.5228 (157.3 min)
#
#     Fold 2/3...
#       [1/5] Data... ✓ (0.0s)
#       [2/5] Model (EfficientNet-B7, leakyrelu)... ✓ (0.7s)
#       [3/5] Optimizer (adamw, L2=0e+00)... ✓
#       [4/5] Loss & Scheduler... ✓
#       [5/5] Training (patience=10, L1=0e+00)...
#         Epoch  1: F1=0.3001, Loss=0.9157
#         Epoch  5: F1=0.3566, Loss=0.2334
#         Epoch 10: F1=0.3641, Loss=0.1239
#         Epoch 15: F1=0.4161, Loss=0.0931
#         Epoch 20: F1=0.4546, Loss=0.0759
#         Epoch 25: F1=0.4996, Loss=0.0720
#         Epoch 30: F1=0.5010, Loss=0.0645
#
#     ✓ Fold 2: F1=0.5012 (157.5 min)
#
#     Fold 3/3...
#       [1/5] Data... ✓ (0.0s)
#       [2/5] Model (EfficientNet-B7, leakyrelu)... ✓ (0.7s)
#       [3/5] Optimizer (adamw, L2=0e+00)... ✓
#       [4/5] Loss & Scheduler... ✓
#       [5/5] Training (patience=10, L1=0e+00)...
#
#     ✗ Error: Expected more than 1 value per channel when training, got input size torch.Size([1, 512])
#
#   Mean F1: 0.3413 ± 0.2415
#   Mean Acc: 0.3819
#   💾 Saved
#
# ================================================================================
# ================================= CONFIG 11/18 =================================
# ================================================================================
#   Optimizer: adamw
#   Activation: leakyrelu
#   L1: 0e+00
#   L2: 1e-04
# --------------------------------------------------------------------------------
#
#     Fold 1/3...
#       [1/5] Data... ✓ (0.0s)
#       [2/5] Model (EfficientNet-B7, leakyrelu)... ✓ (0.7s)
#       [3/5] Optimizer (adamw, L2=1e-04)... ✓
#       [4/5] Loss & Scheduler... ✓
#       [5/5] Training (patience=10, L1=0e+00)...
#         Epoch  1: F1=0.2190, Loss=0.8771
#         Epoch  5: F1=0.3615, Loss=0.2477
#         Epoch 10: F1=0.3438, Loss=0.1237
#         Epoch 15: F1=0.4004, Loss=0.0948
#         Epoch 20: F1=0.4678, Loss=0.0886
#         Epoch 25: F1=0.5150, Loss=0.0786
#         Epoch 30: F1=0.5120, Loss=0.0763
#
#     ✓ Fold 1: F1=0.5168 (162.1 min)
#
#     Fold 2/3...
#       [1/5] Data... ✓ (0.0s)
#       [2/5] Model (EfficientNet-B7, leakyrelu)... ✓ (0.8s)
#       [3/5] Optimizer (adamw, L2=1e-04)... ✓
#       [4/5] Loss & Scheduler... ✓
#       [5/5] Training (patience=10, L1=0e+00)...
#         Epoch  1: F1=0.2645, Loss=0.8761
#         Epoch  5: F1=0.3623, Loss=0.2262
#         Epoch 10: F1=0.3473, Loss=0.1158
#         Epoch 15: F1=0.4288, Loss=0.0922
#         Epoch 20: F1=0.4736, Loss=0.0800
#         Epoch 25: F1=0.4994, Loss=0.0677
#         Epoch 30: F1=0.5061, Loss=0.0747
#
#     ✓ Fold 2: F1=0.5082 (158.6 min)
#
#     Fold 3/3...
#       [1/5] Data... ✓ (0.0s)
#       [2/5] Model (EfficientNet-B7, leakyrelu)... ✓ (0.7s)
#       [3/5] Optimizer (adamw, L2=1e-04)... ✓
#       [4/5] Loss & Scheduler... ✓
#       [5/5] Training (patience=10, L1=0e+00)...
#
#     ✗ Error: Expected more than 1 value per channel when training, got input size torch.Size([1, 512])
#
#   Mean F1: 0.3417 ± 0.2416
#   Mean Acc: 0.3871
#   💾 Saved
#
# ================================================================================
# ================================= CONFIG 12/18 =================================
# ================================================================================
#   Optimizer: adamw
#   Activation: leakyrelu
#   L1: 0e+00
#   L2: 1e-03
# --------------------------------------------------------------------------------
#
#     Fold 1/3...
#       [1/5] Data... ✓ (0.0s)
#       [2/5] Model (EfficientNet-B7, leakyrelu)... ✓ (0.8s)
#       [3/5] Optimizer (adamw, L2=1e-03)... ✓
#       [4/5] Loss & Scheduler... ✓
#       [5/5] Training (patience=10, L1=0e+00)...
#         Epoch  1: F1=0.3163, Loss=0.9065
#         Epoch  5: F1=0.3662, Loss=0.2473
#         Epoch 10: F1=0.3657, Loss=0.1268
#         Epoch 15: F1=0.4358, Loss=0.1014
#         Epoch 20: F1=0.5026, Loss=0.0871
#         Epoch 25: F1=0.5050, Loss=0.0808
#         Epoch 30: F1=0.5180, Loss=0.0749
#
#     ✓ Fold 1: F1=0.5203 (158.9 min)
#
#     Fold 2/3...
#       [1/5] Data... ✓ (0.0s)
#       [2/5] Model (EfficientNet-B7, leakyrelu)... ✓ (0.8s)
#       [3/5] Optimizer (adamw, L2=1e-03)... ✓
#       [4/5] Loss & Scheduler... ✓
#       [5/5] Training (patience=10, L1=0e+00)...
#         Epoch  1: F1=0.2594, Loss=0.9043
#         Epoch  5: F1=0.3600, Loss=0.2466
#         Epoch 10: F1=0.3629, Loss=0.1248
#         Epoch 15: F1=0.4517, Loss=0.0992
#         Epoch 20: F1=0.4797, Loss=0.0756
#         Epoch 25: F1=0.5064, Loss=0.0756
#         Epoch 30: F1=0.5136, Loss=0.0716
#
#     ✓ Fold 2: F1=0.5136 (159.7 min)
#
#     Fold 3/3...
#       [1/5] Data... ✓ (0.0s)
#       [2/5] Model (EfficientNet-B7, leakyrelu)... ✓ (0.7s)
#       [3/5] Optimizer (adamw, L2=1e-03)... ✓
#       [4/5] Loss & Scheduler... ✓
#       [5/5] Training (patience=10, L1=0e+00)...
#
#     ✗ Error: Expected more than 1 value per channel when training, got input size torch.Size([1, 512])
#
#   Mean F1: 0.3446 ± 0.2437
#   Mean Acc: 0.3891
#   💾 Saved
#
# ================================================================================
# ================================= CONFIG 13/18 =================================
# ================================================================================
#   Optimizer: adagrad
#   Activation: relu
#   L1: 0e+00
#   L2: 0e+00
# --------------------------------------------------------------------------------
#
#     Fold 1/3...
#       [1/5] Data... ✓ (0.0s)
#       [2/5] Model (EfficientNet-B7, relu)... ✓ (0.7s)
#       [3/5] Optimizer (adagrad, L2=0e+00)... ✓
#       [4/5] Loss & Scheduler... ✓
#       [5/5] Training (patience=10, L1=0e+00)...
#         Epoch  1: F1=0.3343, Loss=0.8164
#         Epoch  5: F1=0.3488, Loss=0.4869
#         Epoch 10: F1=0.3580, Loss=0.3412
#         Epoch 15: F1=0.3568, Loss=0.2937
#         Epoch 20: F1=0.3553, Loss=0.2561
#         Early stop at epoch 22
#
#     ✓ Fold 1: F1=0.3618 (113.3 min)
#
#     Fold 2/3...
#       [1/5] Data... ✓ (0.0s)
#       [2/5] Model (EfficientNet-B7, relu)... ✓ (0.7s)
#       [3/5] Optimizer (adagrad, L2=0e+00)... ✓
#       [4/5] Loss & Scheduler... ✓
#       [5/5] Training (patience=10, L1=0e+00)...
#         Epoch  1: F1=0.3289, Loss=0.8517
#         Epoch  5: F1=0.3672, Loss=0.5182
#         Epoch 10: F1=0.3688, Loss=0.3595
#         Epoch 15: F1=0.3734, Loss=0.2989
#         Epoch 20: F1=0.3680, Loss=0.2727
#         Early stop at epoch 25
#
#     ✓ Fold 2: F1=0.3734 (129.2 min)
#
#     Fold 3/3...
#       [1/5] Data... ✓ (0.0s)
#       [2/5] Model (EfficientNet-B7, relu)... ✓ (0.7s)
#       [3/5] Optimizer (adagrad, L2=0e+00)... ✓
#       [4/5] Loss & Scheduler... ✓
#       [5/5] Training (patience=10, L1=0e+00)...
#
#     ✗ Error: Expected more than 1 value per channel when training, got input size torch.Size([1, 512])
#
#   Mean F1: 0.2451 ± 0.1734
#   Mean Acc: 0.2388
#   💾 Saved
#
# ================================================================================
# ================================= CONFIG 14/18 =================================
# ================================================================================
#   Optimizer: adagrad
#   Activation: relu
#   L1: 0e+00
#   L2: 1e-04
# --------------------------------------------------------------------------------
#
#     Fold 1/3...
#       [1/5] Data... ✓ (0.0s)
#       [2/5] Model (EfficientNet-B7, relu)... ✓ (0.7s)
#       [3/5] Optimizer (adagrad, L2=1e-04)... ✓
#       [4/5] Loss & Scheduler... ✓
#       [5/5] Training (patience=10, L1=0e+00)...
#         Epoch  1: F1=0.3344, Loss=0.8414
#         Epoch  5: F1=0.3679, Loss=0.4889
#         Epoch 10: F1=0.3687, Loss=0.3351
#         Epoch 15: F1=0.3639, Loss=0.2720
#         Early stop at epoch 18
#
#     ✓ Fold 1: F1=0.3714 (94.0 min)
#
#     Fold 2/3...
#       [1/5] Data... ✓ (0.0s)
#       [2/5] Model (EfficientNet-B7, relu)... ✓ (0.8s)
#       [3/5] Optimizer (adagrad, L2=1e-04)... ✓
#       [4/5] Loss & Scheduler... ✓
#       [5/5] Training (patience=10, L1=0e+00)...
#         Epoch  1: F1=0.3416, Loss=0.8348
#         Epoch  5: F1=0.3668, Loss=0.4703
#         Epoch 10: F1=0.3702, Loss=0.3398
#         Epoch 15: F1=0.3658, Loss=0.2743
#         Epoch 20: F1=0.3657, Loss=0.2495
#         Epoch 25: F1=0.3708, Loss=0.2535
#         Early stop at epoch 29
#
#     ✓ Fold 2: F1=0.3712 (151.0 min)
#
#     Fold 3/3...
#       [1/5] Data... ✓ (0.0s)
#       [2/5] Model (EfficientNet-B7, relu)... ✓ (0.7s)
#       [3/5] Optimizer (adagrad, L2=1e-04)... ✓
#       [4/5] Loss & Scheduler... ✓
#       [5/5] Training (patience=10, L1=0e+00)...
#
#     ✗ Error: Expected more than 1 value per channel when training, got input size torch.Size([1, 512])
#
#   Mean F1: 0.2475 ± 0.1750
#   Mean Acc: 0.2447
#   💾 Saved
#
# ================================================================================
# ================================= CONFIG 15/18 =================================
# ================================================================================
#   Optimizer: adagrad
#   Activation: relu
#   L1: 0e+00
#   L2: 1e-03
# --------------------------------------------------------------------------------
#
#     Fold 1/3...
#       [1/5] Data... ✓ (0.0s)
#       [2/5] Model (EfficientNet-B7, relu)... ✓ (0.7s)
#       [3/5] Optimizer (adagrad, L2=1e-03)... ✓
#       [4/5] Loss & Scheduler... ✓
#       [5/5] Training (patience=10, L1=0e+00)...
#         Epoch  1: F1=0.3375, Loss=0.8673
#         Epoch  5: F1=0.3567, Loss=0.5055
#         Epoch 10: F1=0.3633, Loss=0.3660
#         Epoch 15: F1=0.3634, Loss=0.3087
#         Epoch 20: F1=0.3620, Loss=0.2870
#         Early stop at epoch 24
#
#     ✓ Fold 1: F1=0.3663 (125.1 min)
#
#     Fold 2/3...
#       [1/5] Data... ✓ (0.0s)
#       [2/5] Model (EfficientNet-B7, relu)... ✓ (0.8s)
#       [3/5] Optimizer (adagrad, L2=1e-03)... ✓
#       [4/5] Loss & Scheduler... ✓
#       [5/5] Training (patience=10, L1=0e+00)...
#         Epoch  1: F1=0.3344, Loss=0.8668
#         Epoch  5: F1=0.3684, Loss=0.5197
#         Epoch 10: F1=0.3624, Loss=0.3695
#         Epoch 15: F1=0.3645, Loss=0.3174
#         Early stop at epoch 19
#
#     ✓ Fold 2: F1=0.3696 (99.1 min)
#
#     Fold 3/3...
#       [1/5] Data... ✓ (0.0s)
#       [2/5] Model (EfficientNet-B7, relu)... ✓ (0.7s)
#       [3/5] Optimizer (adagrad, L2=1e-03)... ✓
#       [4/5] Loss & Scheduler... ✓
#       [5/5] Training (patience=10, L1=0e+00)...
#
#     ✗ Error: Expected more than 1 value per channel when training, got input size torch.Size([1, 512])
#
#   Mean F1: 0.2453 ± 0.1735
#   Mean Acc: 0.2433
#   💾 Saved
#
# ================================================================================
# ================================= CONFIG 16/18 =================================
# ================================================================================
#   Optimizer: adagrad
#   Activation: leakyrelu
#   L1: 0e+00
#   L2: 0e+00
# --------------------------------------------------------------------------------
#
#     Fold 1/3...
#       [1/5] Data... ✓ (0.0s)
#       [2/5] Model (EfficientNet-B7, leakyrelu)... ✓ (0.7s)
#       [3/5] Optimizer (adagrad, L2=0e+00)... ✓
#       [4/5] Loss & Scheduler... ✓
#       [5/5] Training (patience=10, L1=0e+00)...
#         Epoch  1: F1=0.3355, Loss=0.8530
#         Epoch  5: F1=0.3606, Loss=0.4902
#         Epoch 10: F1=0.3589, Loss=0.3515
#         Epoch 15: F1=0.3616, Loss=0.2963
#         Epoch 20: F1=0.3653, Loss=0.2580
#         Epoch 25: F1=0.3644, Loss=0.2566
#         Early stop at epoch 30
#
#     ✓ Fold 1: F1=0.3653 (154.2 min)
#
#     Fold 2/3...
#       [1/5] Data... ✓ (0.0s)
#       [2/5] Model (EfficientNet-B7, leakyrelu)... ✓ (0.7s)
#       [3/5] Optimizer (adagrad, L2=0e+00)... ✓
#       [4/5] Loss & Scheduler... ✓
#       [5/5] Training (patience=10, L1=0e+00)...
#         Epoch  1: F1=0.3298, Loss=0.8401
#         Epoch  5: F1=0.3570, Loss=0.4825
#         Epoch 10: F1=0.3606, Loss=0.3451
#         Epoch 15: F1=0.3638, Loss=0.2756
#         Early stop at epoch 19
#
#     ✓ Fold 2: F1=0.3656 (100.1 min)
#
#     Fold 3/3...
#       [1/5] Data... ✓ (0.0s)
#       [2/5] Model (EfficientNet-B7, leakyrelu)... ✓ (0.7s)
#       [3/5] Optimizer (adagrad, L2=0e+00)... ✓
#       [4/5] Loss & Scheduler... ✓
#       [5/5] Training (patience=10, L1=0e+00)...
#
#     ✗ Error: Expected more than 1 value per channel when training, got input size torch.Size([1, 512])
#
#   Mean F1: 0.2436 ± 0.1723
#   Mean Acc: 0.2379
#   💾 Saved
#
# ================================================================================
# ================================= CONFIG 17/18 =================================
# ================================================================================
#   Optimizer: adagrad
#   Activation: leakyrelu
#   L1: 0e+00
#   L2: 1e-04
# --------------------------------------------------------------------------------
#
#     Fold 1/3...
#       [1/5] Data... ✓ (0.0s)
#       [2/5] Model (EfficientNet-B7, leakyrelu)... ✓ (0.7s)
#       [3/5] Optimizer (adagrad, L2=1e-04)... ✓
#       [4/5] Loss & Scheduler... ✓
#       [5/5] Training (patience=10, L1=0e+00)...
#         Epoch  1: F1=0.3327, Loss=0.8409
#         Epoch  5: F1=0.3558, Loss=0.4818
#         Epoch 10: F1=0.3590, Loss=0.3330
#         Epoch 15: F1=0.3599, Loss=0.2745
#         Epoch 20: F1=0.3640, Loss=0.2487
#         Epoch 25: F1=0.3609, Loss=0.2468
#         Epoch 30: F1=0.3626, Loss=0.2349
#
#     ✓ Fold 1: F1=0.3656 (157.5 min)
#
#     Fold 2/3...
#       [1/5] Data... ✓ (0.0s)
#       [2/5] Model (EfficientNet-B7, leakyrelu)... ✓ (0.7s)
#       [3/5] Optimizer (adagrad, L2=1e-04)... ✓
#       [4/5] Loss & Scheduler... ✓
#       [5/5] Training (patience=10, L1=0e+00)...
#         Epoch  1: F1=0.3349, Loss=0.8399
#         Epoch  5: F1=0.3634, Loss=0.4908
#         Epoch 10: F1=0.3630, Loss=0.3363
#         Epoch 15: F1=0.3600, Loss=0.2778
#         Epoch 20: F1=0.3640, Loss=0.2536
#         Epoch 25: F1=0.3653, Loss=0.2463
#         Epoch 30: F1=0.3651, Loss=0.2301
#
#     ✓ Fold 2: F1=0.3658 (156.1 min)
#
#     Fold 3/3...
#       [1/5] Data... ✓ (0.0s)
#       [2/5] Model (EfficientNet-B7, leakyrelu)... ✓ (0.7s)
#       [3/5] Optimizer (adagrad, L2=1e-04)... ✓
#       [4/5] Loss & Scheduler... ✓
#       [5/5] Training (patience=10, L1=0e+00)...
#
#     ✗ Error: Expected more than 1 value per channel when training, got input size torch.Size([1, 512])
#
#   Mean F1: 0.2438 ± 0.1724
#   Mean Acc: 0.2372
#   💾 Saved
#
# ================================================================================
# ================================= CONFIG 18/18 =================================
# ================================================================================
#   Optimizer: adagrad
#   Activation: leakyrelu
#   L1: 0e+00
#   L2: 1e-03
# --------------------------------------------------------------------------------
#
#     Fold 1/3...
#       [1/5] Data... ✓ (0.0s)
#       [2/5] Model (EfficientNet-B7, leakyrelu)... ✓ (0.7s)
#       [3/5] Optimizer (adagrad, L2=1e-03)... ✓
#       [4/5] Loss & Scheduler... ✓
#       [5/5] Training (patience=10, L1=0e+00)...
#         Epoch  1: F1=0.3294, Loss=0.8472
#         Epoch  5: F1=0.3550, Loss=0.4925
#         Epoch 10: F1=0.3643, Loss=0.3454
#         Epoch 15: F1=0.3640, Loss=0.2992
#         Epoch 20: F1=0.3641, Loss=0.2705
#         Early stop at epoch 22
#
#     ✓ Fold 1: F1=0.3692 (114.8 min)
#
#     Fold 2/3...
#       [1/5] Data... ✓ (0.0s)
#       [2/5] Model (EfficientNet-B7, leakyrelu)... ✓ (0.7s)
#       [3/5] Optimizer (adagrad, L2=1e-03)... ✓
#       [4/5] Loss & Scheduler... ✓
#       [5/5] Training (patience=10, L1=0e+00)...
#         Epoch  1: F1=0.3359, Loss=0.8541
#         Epoch  5: F1=0.3636, Loss=0.5176
#         Epoch 10: F1=0.3644, Loss=0.3583
#         Epoch 15: F1=0.3601, Loss=0.2942
#         Epoch 20: F1=0.3604, Loss=0.2720
#         Early stop at epoch 22
#
#     ✓ Fold 2: F1=0.3648 (116.0 min)
#
#     Fold 3/3...
#       [1/5] Data... ✓ (0.0s)
#       [2/5] Model (EfficientNet-B7, leakyrelu)... ✓ (0.7s)
#       [3/5] Optimizer (adagrad, L2=1e-03)... ✓
#       [4/5] Loss & Scheduler... ✓
#       [5/5] Training (patience=10, L1=0e+00)...
#
#     ✗ Error: Expected more than 1 value per channel when training, got input size torch.Size([1, 512])
#
#   Mean F1: 0.2446 ± 0.1730
#   Mean Acc: 0.2418
#   💾 Saved
#
# ================================================================================
# ============================= GRIDSEARCH COMPLETE ==============================
# ================================================================================
# Total time: 83.68 hours

# %%
# CELL 11: Analyze Results

# %%
# ========================================================================
# CELL 11: Analyze Results (WITH PRECISION & RECALL)
# ========================================================================

sorted_results = sorted(all_results, key=lambda x: x['mean_metrics']['f1'], reverse=True)

print("\n" + "="*80)
print(" EFFICIENTNET-B7 GRIDSEARCH RESULTS ".center(80, "="))
print("="*80)

print("\n🏆 TOP 10 CONFIGURATIONS:")
print("="*80)
print(f"{'Rank':<6} {'Optimizer':>10} {'Activation':>12} {'L1':>8} {'L2':>8} "
      f"{'F1':>10} {'Acc':>8} {'Prec':>8} {'Rec':>8}")
print("-"*80)

for i, result in enumerate(sorted_results[:10], 1):
    p = result['params']
    m = result['mean_metrics']
    print(f"{i:<6} {p['optimizer']:>10} {p['activation']:>12} {p['l1_lambda']:>8.0e} "
          f"{p['l2_lambda']:>8.0e} {m['f1']:>10.4f} {m['accuracy']:>8.4f} "
          f"{m['precision']:>8.4f} {m['recall']:>8.4f}")

# Best config
best = sorted_results[0]

print("\n" + "="*80)
print(" BEST EFFICIENTNET-B7 CONFIGURATION ".center(80, "="))
print("="*80)
print(f"  Optimizer:  {best['params']['optimizer']}")
print(f"  Activation: {best['params']['activation']}")
print(f"  L1:         {best['params']['l1_lambda']:.0e}")
print(f"  L2:         {best['params']['l2_lambda']:.0e}")

print(f"\n  F1:        {best['mean_metrics']['f1']:.4f} ± {best['mean_metrics']['f1_std']:.4f}")
print(f"  Accuracy:  {best['mean_metrics']['accuracy']:.4f}")
print(f"  Precision: {best['mean_metrics']['precision']:.4f}")
print(f"  Recall:    {best['mean_metrics']['recall']:.4f}")

# Final comparison
print("\n" + "="*80)
print(" FINAL COMPARISON ".center(80, "="))
print("="*80)
print(f"  EEGNet (baseline):     F1 = 0.3281,  Acc = 0.3154")
print(f"  EEGNet (tuned):        F1 = 0.3892,  Acc = 0.3731")
print(f"  ResNet-101 (tuned):    F1 = 0.5585,  Acc = 0.5921")
print(f"  EfficientNet-B7:       F1 = {best['mean_metrics']['f1']:.4f}, "
      f"Acc = {best['mean_metrics']['accuracy']:.4f}, "
      f"Prec = {best['mean_metrics']['precision']:.4f}, "
      f"Rec = {best['mean_metrics']['recall']:.4f}")

# Verdict
if best['mean_metrics']['f1'] > 0.5585:
    improvement = ((best['mean_metrics']['f1'] - 0.5585) / 0.5585) * 100
    print(f"\n  ✅ EfficientNet-B7 BEATS ResNet-101 by {improvement:.1f}%!")
elif best['mean_metrics']['f1'] > 0.3892:
    print(f"\n  ✅ EfficientNet-B7 beats EEGNet but loses to ResNet-101")
else:
    print(f"\n  ⚠️  EfficientNet-B7 underperformed")

print("\n💾 Results saved to:")
print(f"   {RESULTS_DIR}/efficientnet_gridsearch_final.json")
# Out:
# ================================================================================
# ====================== EFFICIENTNET-B7 GRIDSEARCH RESULTS ======================
# ================================================================================
#
# 🏆 TOP 10 CONFIGURATIONS:
# ================================================================================
# Rank    Optimizer   Activation       L1       L2         F1      Acc     Prec      Rec
# --------------------------------------------------------------------------------
# 1           adamw         relu    0e+00    1e-03     0.3475   0.3922   0.3582   0.3411
# 2           adamw         relu    0e+00    1e-04     0.3472   0.3847   0.3594   0.3452
# 3            adam    leakyrelu    0e+00    0e+00     0.3472   0.3890   0.3544   0.3424
# 4            adam         relu    0e+00    0e+00     0.3465   0.3923   0.3626   0.3364
# 5           adamw    leakyrelu    0e+00    1e-03     0.3446   0.3891   0.3538   0.3385
# 6           adamw    leakyrelu    0e+00    1e-04     0.3417   0.3871   0.3486   0.3395
# 7           adamw    leakyrelu    0e+00    0e+00     0.3413   0.3819   0.3477   0.3378
# 8           adamw         relu    0e+00    0e+00     0.3400   0.3871   0.3507   0.3332
# 9            adam    leakyrelu    0e+00    1e-04     0.2602   0.2592   0.2698   0.3144
# 10        adagrad         relu    0e+00    1e-04     0.2475   0.2447   0.2014   0.3321
#
# ================================================================================
# ====================== BEST EFFICIENTNET-B7 CONFIGURATION ======================
# ================================================================================
#   Optimizer:  adamw
#   Activation: relu
#   L1:         0e+00
#   L2:         1e-03
#
#   F1:        0.3475 ± 0.2457
#   Accuracy:  0.3922
#   Precision: 0.3582
#   Recall:    0.3411
#
# ================================================================================
# =============================== FINAL COMPARISON ===============================
# ================================================================================
#   EEGNet (baseline):     F1 = 0.3281,  Acc = 0.3154
#   EEGNet (tuned):        F1 = 0.3892,  Acc = 0.3731
#   ResNet-101 (tuned):    F1 = 0.5585,  Acc = 0.5921
#   EfficientNet-B7:       F1 = 0.3475, Acc = 0.3922, Prec = 0.3582, Rec = 0.3411
#
#   ⚠️  EfficientNet-B7 underperformed
#
# 💾 Results saved to:
#    efficientnet_gridsearch_results/efficientnet_gridsearch_final.json
